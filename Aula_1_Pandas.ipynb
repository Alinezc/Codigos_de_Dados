# %% [markdown]
# #**Python para Análise de dados(Pandas)**

# %%
# Importando a biblioteca pandas
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/CVS/esus-vepi.LeitoOcupacao_2022.csv") # DADOS ABERTOS: Registro de Ocupação Hospitalar COVID-19 2022
#sep = "" /separador     error_bad_lines=False /ignora erros

# %%
# Visualizando as 5 primeiras linhas
df.head()
# Out:
#    Unnamed: 0         _id           dataNotificacao     cnes  \
# 0      641508  PBGTlqtFBP  2022-01-17T03:00:00.000Z  2379341
# 1     1275198  ipPHkH1yIB  2022-01-05T03:00:00.000Z  2594366
# 2     1290474  oDyVTndNXc  2022-01-01T03:00:50.682Z  2747871
# 3     1290489  cTrwNtInVV  2022-01-01T03:00:08.570Z  2082497
# 4     1290490  CPkiO32WyI  2022-01-01T03:00:14.691Z  2092980
#
#    ocupacaoSuspeitoCli  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 0                 13.0                  8.0                    0.0
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#    ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  ...  \
# 0                    0.0               0.0               1.0  ...
# ...

# %%
#df.rename(columns={}) / modificar nome
df = df.rename(columns={"origem":"Origem","municipioNotificacao":"MunicipioN"})

# %%
df.head() #(pode colocar a quantidade que quiser)
# Out:
#    Unnamed: 0         _id           dataNotificacao     cnes  \
# 0      641508  PBGTlqtFBP  2022-01-17T03:00:00.000Z  2379341
# 1     1275198  ipPHkH1yIB  2022-01-05T03:00:00.000Z  2594366
# 2     1290474  oDyVTndNXc  2022-01-01T03:00:50.682Z  2747871
# 3     1290489  cTrwNtInVV  2022-01-01T03:00:08.570Z  2082497
# 4     1290490  CPkiO32WyI  2022-01-01T03:00:14.691Z  2092980
#
#    ocupacaoSuspeitoCli  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 0                 13.0                  8.0                    0.0
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#    ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  ...  \
# 0                    0.0               0.0               1.0  ...
# ...

# %%
# Total de linhas e colunas
df.shape
# Out:
# (262945, 26)

# %%
# Quantidade de colunas
df.columns
# Out:
# Index(['Unnamed: 0', '_id', 'dataNotificacao', 'cnes', 'ocupacaoSuspeitoCli',
#        'ocupacaoSuspeitoUti', 'ocupacaoConfirmadoCli', 'ocupacaoConfirmadoUti',
#        'ocupacaoCovidUti', 'ocupacaoCovidCli', 'ocupacaoHospitalarUti',
#        'ocupacaoHospitalarCli', 'saidaSuspeitaObitos', 'saidaSuspeitaAltas',
#        'saidaConfirmadaObitos', 'saidaConfirmadaAltas', 'Origem', '_p_usuario',
#        'estadoNotificacao', 'MunicipioN', 'estado', 'municipio', 'excluido',
#        'validado', '_created_at', '_updated_at'],
#       dtype='object')

# %%
# Tipo de dado que esta guardado em cada coluna
df.dtypes
# Out:
# Unnamed: 0                 int64
# _id                       object
# dataNotificacao           object
# cnes                      object
# ocupacaoSuspeitoCli      float64
# ocupacaoSuspeitoUti      float64
# ocupacaoConfirmadoCli    float64
# ocupacaoConfirmadoUti    float64
# ocupacaoCovidUti         float64
# ocupacaoCovidCli         float64
# ocupacaoHospitalarUti    float64
# ocupacaoHospitalarCli    float64
# saidaSuspeitaObitos      float64
# saidaSuspeitaAltas       float64
# saidaConfirmadaObitos    float64
# saidaConfirmadaAltas     float64
# Origem                    object
# _p_usuario                object
# estadoNotificacao         object
# MunicipioN                object
# estado                    object
# municipio                 object
# excluido                    bool
# validado                    bool
# _created_at               object
# _updated_at               object
# dtype: object

# %%
# Retorna as  ultimas linhas
df.tail()
# Out:
#         Unnamed: 0         _id           dataNotificacao     cnes  \
# 262940     1562803  zem1EIpy05  2022-10-08T03:00:00.000Z  2334321
# 262941     1562804  Axo7HzssmX  2022-10-09T03:00:40.284Z  0226491
# 262942     1562805  DyeeECcC2v  2022-10-09T03:00:28.878Z  2118319
# 262943     1562806  AsvwMIKOJd  2022-10-09T03:00:07.737Z  2363070
# 262944     1562807  TOEyImsi2L  2022-10-09T03:00:42.860Z  2336812
#
#         ocupacaoSuspeitoCli  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 262940                  NaN                  NaN                    NaN
# 262941                  NaN                  NaN                    NaN
# 262942                  NaN                  NaN                    NaN
# 262943                  NaN                  NaN                    NaN
# 262944                  NaN                  NaN                    NaN
#
#         ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  ...  \
# ...

# %%
# Retorna informaçoes estatísticas
df.describe()
# Out:
#          Unnamed: 0  ocupacaoSuspeitoCli  ocupacaoSuspeitoUti  \
# count  2.629450e+05                  1.0                  1.0
# mean   1.430198e+06                 13.0                  8.0
# std    7.747621e+04                  NaN                  NaN
# min    6.415080e+05                 13.0                  8.0
# 25%    1.365111e+06                 13.0                  8.0
# 50%    1.431174e+06                 13.0                  8.0
# 75%    1.497052e+06                 13.0                  8.0
# max    1.562807e+06                 13.0                  8.0
#
#        ocupacaoConfirmadoCli  ocupacaoConfirmadoUti  ocupacaoCovidUti  \
# count                    1.0                    1.0     262945.000000
# mean                     0.0                    0.0          2.130487
# std                      NaN                    NaN          7.181320
# min                      0.0                    0.0         -7.000000
# ...

# %%
# Retorna apenas valores unicos
df["estado"].unique()
# Out:
# array(['Santa Catarina', 'Paraná', 'São Paulo', 'Rio Grande do Sul',
#        'Minas Gerais', 'Sergipe', 'Rio de Janeiro', 'Goiás', 'Alagoas',
#        'Espírito Santo', 'Ceará', 'Mato Grosso do Sul', 'Pernambuco',
#        'Bahia', 'Piauí', 'Amazonas', 'Rondônia', 'Paraíba', 'Acre',
#        'Pará', 'Rio Grande do Norte', 'Maranhão', 'Tocantins',
#        'Distrito Federal', 'Mato Grosso', 'Amapá', 'Roraima'],
#       dtype=object)

# %%
# Fazer filtro
Sp = df.loc[df["estado"] == "São Paulo"]
Sp.head()
# Out:
#    Unnamed: 0         _id           dataNotificacao     cnes  \
# 2     1290474  oDyVTndNXc  2022-01-01T03:00:50.682Z  2747871
# 3     1290489  cTrwNtInVV  2022-01-01T03:00:08.570Z  2082497
# 4     1290490  CPkiO32WyI  2022-01-01T03:00:14.691Z  2092980
# 7     1290496  phtJiP6gpe  2022-01-01T03:00:21.351Z  2078511
# 8     1290498  DjdziRthvF  2022-01-01T03:00:37.452Z  2082438
#
#    ocupacaoSuspeitoCli  ocupacaoSuspeitoUti  ocupacaoConfirmadoCli  \
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
# 7                  NaN                  NaN                    NaN
# 8                  NaN                  NaN                    NaN
#
#    ocupacaoConfirmadoUti  ocupacaoCovidUti  ocupacaoCovidCli  ...  \
# 2                    NaN               1.0               9.0  ...
# ...

# %%
Sp["estado"].unique()
# Out:
# array(['São Paulo'], dtype=object)

# %%
# Agrupamento de dados
df.groupby("municipio")["estado"].nunique()
# Out:
# municipio
# Abadia de Goiás          1
# Acarape                  1
# Acreúna                  1
# Adamantina               1
# Afogados da Ingazeira    1
#                         ..
# Água Doce                1
# Águas Formosas           1
# Águas Lindas de Goiás    1
# Águas de Lindóia         1
# Álvares Machado          1
# Name: estado, Length: 1206, dtype: int64

# %%
# Media  
df.groupby("ocupacaoSuspeitoCli")["ocupacaoCovidCli"].mean() # erro com string
# Out:
# ocupacaoSuspeitoCli
# 13.0    1.0
# Name: ocupacaoCovidCli, dtype: float64

# %%
df["ocupacaoCovidCli"].mean()
# Out:
# 3.111688756203769

# %%
#SOMAR
df["ocupacaoCovidCli"].sum()
# Out:
# 818203.0
